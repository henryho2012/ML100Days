# %% [markdown]
# ## 作業目標：搭建一個bag of words模型

# %% [markdown]
# ---

# %%
import pandas as pd
import nltk
#nltk.download()
import numpy as np
dataset=pd.read_csv('Restaurant_Reviews.tsv',delimiter='\t',quoting=3)
corpus=dataset['Review'].values

# %% [markdown]
# ### 從文本中取出所有單字

# %%
whole_words = []
for sentence in corpus:
    tokenized_sentence = nltk.word_tokenize(sentence)
    for word in tokenized_sentence:
        whole_words.append(word)

# %% [markdown]
# ### 移除重複單字

# %%
whole_words = set(whole_words)
print('共有{}個單字'.format(len(whole_words)))
# Out:
# 共有2356個單字

# %% [markdown]
# ### 建立字典使每一個單字有對應數值

# %%
word_index = {}
index_word = {}
n = 0
for word in whole_words:
    word_index[word] = n 
    index_word[n] = word
    n+=1

# %%
word_index
# Out:
# {'couples': 0,
#  'Chinese': 1,
#  '23': 2,
#  'avoided': 3,
#  'tasteless': 4,
#  'sauces': 5,
#  '10': 6,
#  'further': 7,
#  'located': 8,
#  'perfect': 9,
#  'revisiting': 10,
#  'these': 11,
#  'shops': 12,
#  'occasional': 13,
#  'fail': 14,
#  'it': 15,
#  'prepared': 16,
#  'have': 17,
#  'lovers': 18,
#  'Must': 19,
#  'foods': 20,
#  'workers': 21,
#  'mistake': 22,
#  'whatsoever': 23,
#  'guys': 24,
#  'let': 25,
#  'seasoning': 26,
#  'genuinely': 27,
#  'How': 28,
#  'venturing': 29,
#  'suggestions': 30,
#  'worth': 31,
#  'always': 32,
#  'AN': 33,
#  'All': 34,
#  'FREEZING': 35,
#  'chicken': 36,
#  'Damn': 37,
#  'tomato': 38,
#  'lettuce': 39,
#  'recommendation': 40,
#  'promptly': 41,
#  'chains': 42,
#  'atmosphere': 43,
#  '1/2': 44,
#  'bites': 45,
#  'gloves.Everything': 46,
#  'minutes': 47,
#  'Level': 48,
#  'easily': 49,
#  'So': 50,
#  'dedicated': 51,
#  'BETTER': 52,
#  'boxes': 53,
#  'mayo': 54,
#  'Italian': 55,
#  'and': 56,
#  'overhaul': 57,
#  'drag': 58,
#  'containers': 59,
#  'most': 60,
#  'wayyy': 61,
#  'bucks': 62,
#  'In': 63,
#  'Each': 64,
#  'watered': 65,
#  'ladies': 66,
#  'i': 67,
#  'Dylan': 68,
#  'cover': 69,
#  'Ordered': 70,
#  'Con': 71,
#  'management': 72,
#  'delightful': 73,
#  'told': 74,
#  'gross': 75,
#  'Special': 76,
#  'warnings': 77,
#  'setting': 78,
#  'degree': 79,
#  'Sooooo': 80,
#  'After': 81,
#  'Owner': 82,
#  'Steiners': 83,
#  'positive': 84,
#  'low-key': 85,
#  'incredible': 86,
#  'how': 87,
#  'underwhelming': 88,
#  'callings': 89,
#  'hand': 90,
#  'Palm': 91,
#  'green': 92,
#  'Phenomenal': 93,
#  'mac': 94,
#  'perfection': 95,
#  'No': 96,
#  'dish': 97,
#  'FORWARD': 98,
#  'guess': 99,
#  'airline': 100,
#  'comfortable': 101,
#  'quite': 102,
#  'outshining': 103,
#  'refried': 104,
#  'Heart': 105,
#  '2': 106,
#  'quickly': 107,
#  'there': 108,
#  'pace': 109,
#  'liking': 110,
#  'Hot': 111,
#  'visited': 112,
#  'grab': 113,
#  'pho': 114,
#  'somewhat': 115,
#  'needs': 116,
#  'bug': 117,
#  'favorite': 118,
#  'STEP': 119,
#  'shirt': 120,
#  'buying': 121,
#  'alone': 122,
#  'suggest': 123,
#  'front': 124,
#  'later': 125,
#  'her': 126,
#  'falling': 127,
#  'glad': 128,
#  'cramming': 129,
#  'world': 130,
#  'transcendant': 131,
#  'Spend': 132,
#  'Las': 133,
#  'second': 134,
#  'Burger': 135,
#  'turn': 136,
#  'pissd': 137,
#  'ourselves': 138,
#  'sewer': 139,
#  'next': 140,
#  'bowl': 141,
#  'cash': 142,
#  'flavorless': 143,
#  'AND': 144,
#  'Mandalay': 145,
#  'handed': 146,
#  'far': 147,
#  'eyed': 148,
#  'gyros': 149,
#  'excellent': 150,
#  'Terrible': 151,
#  'spring': 152,
#  'readers': 153,
#  'Perhaps': 154,
#  'beautifully': 155,
#  'interesting': 156,
#  'AYCE': 157,
#  'tea': 158,
#  'water': 159,
#  'sangria': 160,
#  'takeout': 161,
#  'elegantly': 162,
#  'outstanding': 163,
#  'must': 164,
#  'anyone': 165,
#  'college': 166,
#  'Our': 167,
#  'email': 168,
#  'considering': 169,
#  'cooked': 170,
#  'raving': 171,
#  'Sun': 172,
#  'tables': 173,
#  'decide': 174,
#  '40': 175,
#  ',': 176,
#  'asking': 177,
#  'double': 178,
#  'imagine': 179,
#  'Bouchon': 180,
#  'combo': 181,
#  'unfortunately': 182,
#  'eat': 183,
#  ')': 184,
#  'worst/annoying': 185,
#  'Stopped': 186,
#  '7': 187,
#  'mozzarella': 188,
#  'which': 189,
#  'leftover': 190,
#  'flavorful': 191,
#  'Love': 192,
#  'Rick': 193,
#  'golden-crispy': 194,
#  'yellowtail': 195,
#  'Ryan': 196,
#  'final': 197,
#  'family': 198,
#  'industry': 199,
#  'apology': 200,
#  'prepare': 201,
#  'send': 202,
#  'feel': 203,
#  'Mexican': 204,
#  'nicest': 205,
#  'reheated': 206,
#  'drawing': 207,
#  'Japanese': 208,
#  'over-hip': 209,
#  'disgrace': 210,
#  'relax': 211,
#  'disgraceful': 212,
#  'disgusting': 213,
#  'voted': 214,
#  'chocolate': 215,
#  'Coming': 216,
#  'space': 217,
#  'reminded': 218,
#  'feeling': 219,
#  'closed': 220,
#  'luck': 221,
#  'Luke': 222,
#  'Nargile': 223,
#  'none': 224,
#  'towards': 225,
#  'obviously': 226,
#  'Be': 227,
#  'light': 228,
#  'TOTAL': 229,
#  'help': 230,
#  'pricey': 231,
#  'home': 232,
#  'tuna': 233,
#  'experienced': 234,
#  'ate': 235,
#  'portion': 236,
#  'servers': 237,
#  'amazing': 238,
#  'Ample': 239,
#  'happier': 240,
#  'gratuity': 241,
#  'bathroom': 242,
#  'deal': 243,
#  'quick': 244,
#  'Poor': 245,
#  'styrofoam': 246,
#  'upgrading': 247,
#  'Lastly': 248,
#  'tolerance': 249,
#  'impressed': 250,
#  'three': 251,
#  'BACK': 252,
#  'Pineapple': 253,
#  'does': 254,
#  'potatoes': 255,
#  'Third': 256,
#  'Mmmm': 257,
#  'receives': 258,
#  'plus': 259,
#  'pancake': 260,
#  'Mediterranean': 261,
#  'authentic': 262,
#  'Interesting': 263,
#  'crusty': 264,
#  'Cotta': 265,
#  'crispy': 266,
#  'Madison': 267,
#  'fry': 268,
#  'if': 269,
#  'cheated': 270,
#  'chewy': 271,
#  'Tonight': 272,
#  'rest': 273,
#  'works': 274,
#  'rapidly': 275,
#  'passed': 276,
#  'vain': 277,
#  'trippy': 278,
#  'poorly': 279,
#  'disappointing': 280,
#  'lacked': 281,
#  'THAT': 282,
#  'Hopefully': 283,
#  'binge': 284,
#  'quit': 285,
#  'untoasted': 286,
#  'hereas': 287,
#  'brings': 288,
#  'yay': 289,
#  'saganaki': 290,
#  'Sushi': 291,
#  'review': 292,
#  'Caballero': 293,
#  'actual': 294,
#  'verge': 295,
#  'arrived': 296,
#  '.': 297,
#  'area': 298,
#  'honor': 299,
#  'salsa': 300,
#  'shoe': 301,
#  'seasonal': 302,
#  'sauce': 303,
#  'bus': 304,
#  'hooked': 305,
#  'quantity': 306,
#  'behind': 307,
#  'bamboo': 308,
#  'pastry': 309,
#  'By': 310,
#  'spotty': 311,
#  'grossed': 312,
#  'Four': 313,
#  'beautiful': 314,
#  'properly': 315,
#  'refrained': 316,
#  '.off': 317,
#  'store': 318,
#  'free': 319,
#  'dinners': 320,
#  'working/eating': 321,
#  'gluten': 322,
#  'prime': 323,
#  'thru': 324,
#  'instead': 325,
#  'airport': 326,
#  'price': 327,
#  'eggs': 328,
#  'over-priced': 329,
#  'editing': 330,
#  'glass': 331,
#  'powdered': 332,
#  'quaint': 333,
#  'looks': 334,
#  '11.99': 335,
#  'Boy': 336,
#  'incredibly': 337,
#  'forty': 338,
#  'latte': 339,
#  'Similarly': 340,
#  'lawyers': 341,
#  'honestly': 342,
#  'low': 343,
#  'papers': 344,
#  'shrimp': 345,
#  'clean': 346,
#  'Furthermore': 347,
#  'pepper': 348,
#  'concept': 349,
#  'unhealthy': 350,
#  'mein': 351,
#  'Ha': 352,
#  'friendly': 353,
#  'besides': 354,
#  'ridiculous': 355,
#  'vacant': 356,
#  'pink': 357,
#  'But': 358,
#  'There': 359,
#  'screwed': 360,
#  'beyond': 361,
#  '-': 362,
#  'where': 363,
#  'gooodd': 364,
#  'ever': 365,
#  'boy': 366,
#  'warm': 367,
#  'here': 368,
#  'dusted': 369,
#  'potato': 370,
#  'inside': 371,
#  'bill': 372,
#  'Needless': 373,
#  'Toast': 374,
#  'rice': 375,
#  'offered': 376,
#  'go': 377,
#  'got': 378,
#  'boot': 379,
#  'hella': 380,
#  'yummy': 381,
#  'am': 382,
#  'idea': 383,
#  'truly': 384,
#  'forth': 385,
#  'iced': 386,
#  'perfectly': 387,
#  'cheese': 388,
#  'multiple': 389,
#  'meatballs': 390,
#  'deliver': 391,
#  'together': 392,
#  'fruit': 393,
#  'Gourmet': 394,
#  'one': 395,
#  'high': 396,
#  'gotten': 397,
#  'decided': 398,
#  'San': 399,
#  'paper': 400,
#  'fair': 401,
#  'hardly': 402,
#  'nasty': 403,
#  'Definitely': 404,
#  'please': 405,
#  'curry': 406,
#  'experience': 407,
#  'dead': 408,
#  'apologize': 409,
#  'dollars': 410,
#  'cafe': 411,
#  'publicly': 412,
#  'sub': 413,
#  'events': 414,
#  'exactly': 415,
#  'served': 416,
#  'but': 417,
#  'tiny': 418,
#  'Avoid': 419,
#  'scallop': 420,
#  'courteous': 421,
#  'round': 422,
#  'regular': 423,
#  'or': 424,
#  'medium': 425,
#  'Every': 426,
#  'My': 427,
#  'over-whelm': 428,
#  'concern': 429,
#  'boba': 430,
#  'relationship': 431,
#  'wrong': 432,
#  'steakhouse': 433,
#  'At': 434,
#  'Food': 435,
#  'tap': 436,
#  'been-stepped-in-and-tracked-everywhere': 437,
#  'Seafood': 438,
#  'sandwiches': 439,
#  'set': 440,
#  'someone': 441,
#  'better': 442,
#  'spicy': 443,
#  '3/4ths': 444,
#  'struggle': 445,
#  'Go': 446,
#  'martini': 447,
#  'running': 448,
#  'any': 449,
#  'silently': 450,
#  'accommodations': 451,
#  'IN': 452,
#  'MUST': 453,
#  "'s": 454,
#  '10+': 455,
#  'simple': 456,
#  'angry': 457,
#  'almost': 458,
#  'rushed': 459,
#  'customers': 460,
#  'Lemon': 461,
#  'pop': 462,
#  'who': 463,
#  'NONE': 464,
#  'Casino': 465,
#  'Sorry': 466,
#  'operation': 467,
#  'she': 468,
#  '$': 469,
#  'tragedy': 470,
#  '..ohhh': 471,
#  'worries': 472,
#  'want': 473,
#  'place': 474,
#  'Reasonably': 475,
#  'non-customer': 476,
#  'wash': 477,
#  'those': 478,
#  'accomodate': 479,
#  'haunt': 480,
#  'Plus': 481,
#  'do': 482,
#  'shall': 483,
#  'Bloody': 484,
#  'NOW': 485,
#  'Awesome': 486,
#  'another': 487,
#  'Crystals': 488,
#  'might': 489,
#  'buffets': 490,
#  'side': 491,
#  'They': 492,
#  'pucks': 493,
#  'not': 494,
#  'seating': 495,
#  'last': 496,
#  'rich': 497,
#  'Rock': 498,
#  'yellow': 499,
#  'caring': 500,
#  'fuzzy': 501,
#  'that': 502,
#  'wrap': 503,
#  'talk': 504,
#  'Christmas': 505,
#  'Same': 506,
#  'pretty': 507,
#  'complain': 508,
#  'cause': 509,
#  'being': 510,
#  'hummus': 511,
#  "'re": 512,
#  'about': 513,
#  'entrees': 514,
#  'inspired': 515,
#  'bottom': 516,
#  'Highly': 517,
#  "'ve": 518,
#  'sunglasses': 519,
#  'blame': 520,
#  'much': 521,
#  'showed': 522,
#  'High-quality': 523,
#  'skimp': 524,
#  'self': 525,
#  'has': 526,
#  'tasty': 527,
#  'name': 528,
#  'Tasted': 529,
#  'Delicious': 530,
#  'between': 531,
#  'although': 532,
#  'wagyu': 533,
#  'eggplant': 534,
#  'years': 535,
#  'horrible': 536,
#  'connoisseur': 537,
#  '2007': 538,
#  'fine': 539,
#  'mood': 540,
#  'others': 541,
#  'Thai': 542,
#  'breaks': 543,
#  'manager': 544,
#  'wire': 545,
#  'boiled': 546,
#  'Mary': 547,
#  'One': 548,
#  'Shop': 549,
#  'corporation': 550,
#  'smaller': 551,
#  'sandwich': 552,
#  'cut': 553,
#  'theft': 554,
#  'flavourful': 555,
#  'end': 556,
#  'third': 557,
#  'Bean': 558,
#  'Pho': 559,
#  'sad': 560,
#  'batter': 561,
#  'waitresses': 562,
#  'ok': 563,
#  'wish': 564,
#  'profound': 565,
#  'staying': 566,
#  'privileged': 567,
#  'smelled': 568,
#  'looking': 569,
#  'bank': 570,
#  'devine': 571,
#  'fucking': 572,
#  'dates': 573,
#  'seated': 574,
#  'tots': 575,
#  'andddd': 576,
#  'wedges': 577,
#  'dessert': 578,
#  'plantains': 579,
#  'yum': 580,
#  'satisfied': 581,
#  'sure': 582,
#  'try': 583,
#  'puréed': 584,
#  'sound': 585,
#  'classic': 586,
#  'had': 587,
#  '30s': 588,
#  'ahead': 589,
#  'public': 590,
#  'jerk': 591,
#  'fish': 592,
#  'vibe': 593,
#  'strings': 594,
#  'plethora': 595,
#  'pile': 596,
#  'eel': 597,
#  'bone': 598,
#  'dough': 599,
#  'Really': 600,
#  'Disappointing': 601,
#  'bad': 602,
#  'shopping': 603,
#  'Phoenix': 604,
#  'supposed': 605,
#  'bakery': 606,
#  'reading': 607,
#  'meatloaf': 608,
#  'return': 609,
#  'prompt': 610,
#  'bar': 611,
#  'EVER': 612,
#  'donut': 613,
#  'sugar': 614,
#  'myself': 615,
#  'stars': 616,
#  'Would': 617,
#  'hoping': 618,
#  'imaginative': 619,
#  'yukon': 620,
#  'calligraphy': 621,
#  'wings': 622,
#  'SHOULD': 623,
#  'occasions': 624,
#  'combination': 625,
#  'beer': 626,
#  'appetizer': 627,
#  'top': 628,
#  'decision': 629,
#  'understand': 630,
#  'long': 631,
#  'violinists': 632,
#  'stay': 633,
#  'patio': 634,
#  'lot': 635,
#  'hardest': 636,
#  'stuff': 637,
#  'been': 638,
#  'exceptional': 639,
#  'wildly': 640,
#  '90': 641,
#  'WHAT': 642,
#  'lack': 643,
#  'spice': 644,
#  'choux': 645,
#  'apart': 646,
#  'Long': 647,
#  'Joey': 648,
#  'greasy': 649,
#  'Ninja': 650,
#  'Flower': 651,
#  'restaurant': 652,
#  'date': 653,
#  'I': 654,
#  'wound': 655,
#  'Steak': 656,
#  'Based': 657,
#  'meat': 658,
#  'still': 659,
#  'worse': 660,
#  'Soi': 661,
#  'spices': 662,
#  'sashimi': 663,
#  'acknowledged': 664,
#  'providing': 665,
#  'carbs': 666,
#  'app': 667,
#  'Bad': 668,
#  'opposed': 669,
#  'business': 670,
#  'outdoor': 671,
#  'GREAT': 672,
#  'street': 673,
#  'oysters': 674,
#  'super': 675,
#  'gone': 676,
#  'raspberry': 677,
#  'Roll': 678,
#  'possible': 679,
#  'style': 680,
#  'performed': 681,
#  'fluffy': 682,
#  'godfathers': 683,
#  'enough..': 684,
#  'milk': 685,
#  'Nothing': 686,
#  'accident': 687,
#  'sore': 688,
#  'Host': 689,
#  'while': 690,
#  'Maria': 691,
#  'poop': 692,
#  'bloddy': 693,
#  'Experience': 694,
#  'appealing': 695,
#  'people': 696,
#  'like': 697,
#  'Hawaiian': 698,
#  'TV': 699,
#  'Great': 700,
#  'use': 701,
#  'boring': 702,
#  'professional': 703,
#  'find': 704,
#  'relleno': 705,
#  'clue': 706,
#  'Overpriced': 707,
#  'were': 708,
#  'right': 709,
#  'Which': 710,
#  'choose': 711,
#  'trips': 712,
#  'mediocre': 713,
#  'favor': 714,
#  'cakes': 715,
#  'new': 716,
#  'power': 717,
#  'Everything': 718,
#  'fell': 719,
#  'steaks': 720,
#  'short': 721,
#  'recommending': 722,
#  'Eggplant': 723,
#  'downside': 724,
#  'legit': 725,
#  'itself': 726,
#  'happy': 727,
#  'platter': 728,
#  'paid': 729,
#  'sticks': 730,
#  'recall': 731,
#  'despicable': 732,
#  'cashier': 733,
#  'menu': 734,
#  'menus': 735,
#  'pastas': 736,
#  'Those': 737,
#  'blue': 738,
#  'Strike': 739,
#  'salmon': 740,
#  'Cod': 741,
#  'cost': 742,
#  'ones': 743,
#  'living': 744,
#  'Scottsdale': 745,
#  'done': 746,
#  'sexy': 747,
#  'The': 748,
#  'under': 749,
#  'Although': 750,
#  'absolutely': 751,
#  'businesses': 752,
#  'dreamed': 753,
#  'solid': 754,
#  'extensive': 755,
#  'me': 756,
#  'companions': 757,
#  'hot': 758,
#  'jewel': 759,
#  'oh': 760,
#  'sucked': 761,
#  'hour': 762,
#  'coupons': 763,
#  'personable': 764,
#  'Plater': 765,
#  'overwhelmed': 766,
#  'reasonably': 767,
#  'MANY': 768,
#  'fantastic': 769,
#  'recommended': 770,
#  'joy': 771,
#  '.way': 772,
#  'Hands': 773,
#  'of': 774,
#  'eyes': 775,
#  'Sadly': 776,
#  'was': 777,
#  'hair': 778,
#  'MGM': 779,
#  'giant': 780,
#  'neither': 781,
#  'nutshell': 782,
#  'why': 783,
#  'fairly': 784,
#  'REAL': 785,
#  'gold': 786,
#  'absolutley': 787,
#  'cream': 788,
#  'selections': 789,
#  'Cape': 790,
#  'Best': 791,
#  'Area': 792,
#  'market': 793,
#  'chefs': 794,
#  'Baba': 795,
#  'avoid': 796,
#  'peach': 797,
#  'What': 798,
#  'food': 799,
#  'left': 800,
#  'chickens': 801,
#  'thing': 802,
#  'T.': 803,
#  '70+': 804,
#  'tartare': 805,
#  '1979': 806,
#  'up': 807,
#  'NASTY': 808,
#  'amount': 809,
#  'salty': 810,
#  'hopes': 811,
#  'Brushfire': 812,
#  'refreshing': 813,
#  'wants': 814,
#  'see': 815,
#  'case': 816,
#  'serving': 817,
#  'patty': 818,
#  'complaints': 819,
#  'TOLD': 820,
#  '15': 821,
#  'hearts': 822,
#  'smoothies': 823,
#  'rating': 824,
#  'did': 825,
#  'slow': 826,
#  'small': 827,
#  'Come': 828,
#  'tasted': 829,
#  'an': 830,
#  'person': 831,
#  'cuisine': 832,
#  'menu/': 833,
#  'filling': 834,
#  'Grill': 835,
#  'ravoli': 836,
#  'As': 837,
#  'Otto': 838,
#  'Blah': 839,
#  'winner': 840,
#  'so': 841,
#  'warmer': 842,
#  'close': 843,
#  '7.85': 844,
#  'strangers': 845,
#  'soon': 846,
#  'parents': 847,
#  'overall': 848,
#  'We': 849,
#  'spaghetti': 850,
#  'deep': 851,
#  'pecan': 852,
#  'Stars': 853,
#  'summary': 854,
#  'club': 855,
#  'places': 856,
#  'somehow': 857,
#  'olives': 858,
#  'less': 859,
#  'reservation': 860,
#  'rge': 861,
#  'ignore': 862,
#  'longer': 863,
#  'Risotto': 864,
#  'become': 865,
#  'attack': 866,
#  'looked': 867,
#  'postinos': 868,
#  'whether': 869,
#  'steak': 870,
#  'appetizers': 871,
#  'disbelief': 872,
#  'unique': 873,
#  'Vegas': 874,
#  'class': 875,
#  '30': 876,
#  'you': 877,
#  'enough': 878,
#  'welcome': 879,
#  'mojitos': 880,
#  'satifying': 881,
#  'cocktails': 882,
#  'Magazine': 883,
#  'mall': 884,
#  'Eew': 885,
#  'batch': 886,
#  'hottest': 887,
#  'took': 888,
#  'full': 889,
#  'brother': 890,
#  'chipolte': 891,
#  'WORST': 892,
#  'uploaded': 893,
#  'our': 894,
#  'guacamole': 895,
#  'tops': 896,
#  'spicier': 897,
#  'shots': 898,
#  'now': 899,
#  'we': 900,
#  'ethic': 901,
#  'Buldogis': 902,
#  'VERY': 903,
#  'twice': 904,
#  'Pizza': 905,
#  'hip': 906,
#  'flavors': 907,
#  'missed': 908,
#  'venture': 909,
#  'Now': 910,
#  'Mushroom': 911,
#  'coming': 912,
#  'North': 913,
#  'pleased': 914,
#  'Not': 915,
#  'spots': 916,
#  'received': 917,
#  'Taco': 918,
#  'section': 919,
#  'crowds': 920,
#  'weekend': 921,
#  'ordering': 922,
#  'smoke': 923,
#  'LEGIT': 924,
#  'at': 925,
#  'accountant': 926,
#  'correct': 927,
#  'handmade': 928,
#  'outta': 929,
#  'rolled': 930,
#  'Edinburgh': 931,
#  'Paying': 932,
#  'point': 933,
#  'boyfriend': 934,
#  'Anyways': 935,
#  'stupid': 936,
#  'disappointed': 937,
#  'maybe': 938,
#  'Why': 939,
#  'military': 940,
#  'vegetables': 941,
#  'ESTABLISHMENT': 942,
#  'She': 943,
#  'difference': 944,
#  'Extremely': 945,
#  'enjoyable': 946,
#  'orders': 947,
#  'forever': 948,
#  'loudly': 949,
#  'carpaccio': 950,
#  'ignored': 951,
#  'Only': 952,
#  'modern': 953,
#  'memory': 954,
#  'capers': 955,
#  'mention': 956,
#  'can': 957,
#  'Worse': 958,
#  '.the': 959,
#  '6': 960,
#  'Shrimp-': 961,
#  'atmosphere.1': 962,
#  'FS': 963,
#  'leather': 964,
#  'frozen': 965,
#  'Macarons': 966,
#  'fact': 967,
#  'slaw': 968,
#  'honest': 969,
#  'forgetting': 970,
#  'bartenders': 971,
#  'anything': 972,
#  'gem': 973,
#  'piece': 974,
#  'attention': 975,
#  'sides': 976,
#  '``': 977,
#  'HOUR': 978,
#  'thanks': 979,
#  'Philadelphia': 980,
#  'duck': 981,
#  'live': 982,
#  'BBQ': 983,
#  'Café': 984,
#  'wonderful': 985,
#  'Aria': 986,
#  'need': 987,
#  'contained': 988,
#  'returning': 989,
#  'come': 990,
#  'trimmed': 991,
#  'because': 992,
#  'seemed': 993,
#  'smeared': 994,
#  'efficient': 995,
#  'loves': 996,
#  '*': 997,
#  'NO': 998,
#  'delish': 999,
#  ...}

# %%
index_word
# Out:
# {0: 'couples',
#  1: 'Chinese',
#  2: '23',
#  3: 'avoided',
#  4: 'tasteless',
#  5: 'sauces',
#  6: '10',
#  7: 'further',
#  8: 'located',
#  9: 'perfect',
#  10: 'revisiting',
#  11: 'these',
#  12: 'shops',
#  13: 'occasional',
#  14: 'fail',
#  15: 'it',
#  16: 'prepared',
#  17: 'have',
#  18: 'lovers',
#  19: 'Must',
#  20: 'foods',
#  21: 'workers',
#  22: 'mistake',
#  23: 'whatsoever',
#  24: 'guys',
#  25: 'let',
#  26: 'seasoning',
#  27: 'genuinely',
#  28: 'How',
#  29: 'venturing',
#  30: 'suggestions',
#  31: 'worth',
#  32: 'always',
#  33: 'AN',
#  34: 'All',
#  35: 'FREEZING',
#  36: 'chicken',
#  37: 'Damn',
#  38: 'tomato',
#  39: 'lettuce',
#  40: 'recommendation',
#  41: 'promptly',
#  42: 'chains',
#  43: 'atmosphere',
#  44: '1/2',
#  45: 'bites',
#  46: 'gloves.Everything',
#  47: 'minutes',
#  48: 'Level',
#  49: 'easily',
#  50: 'So',
#  51: 'dedicated',
#  52: 'BETTER',
#  53: 'boxes',
#  54: 'mayo',
#  55: 'Italian',
#  56: 'and',
#  57: 'overhaul',
#  58: 'drag',
#  59: 'containers',
#  60: 'most',
#  61: 'wayyy',
#  62: 'bucks',
#  63: 'In',
#  64: 'Each',
#  65: 'watered',
#  66: 'ladies',
#  67: 'i',
#  68: 'Dylan',
#  69: 'cover',
#  70: 'Ordered',
#  71: 'Con',
#  72: 'management',
#  73: 'delightful',
#  74: 'told',
#  75: 'gross',
#  76: 'Special',
#  77: 'warnings',
#  78: 'setting',
#  79: 'degree',
#  80: 'Sooooo',
#  81: 'After',
#  82: 'Owner',
#  83: 'Steiners',
#  84: 'positive',
#  85: 'low-key',
#  86: 'incredible',
#  87: 'how',
#  88: 'underwhelming',
#  89: 'callings',
#  90: 'hand',
#  91: 'Palm',
#  92: 'green',
#  93: 'Phenomenal',
#  94: 'mac',
#  95: 'perfection',
#  96: 'No',
#  97: 'dish',
#  98: 'FORWARD',
#  99: 'guess',
#  100: 'airline',
#  101: 'comfortable',
#  102: 'quite',
#  103: 'outshining',
#  104: 'refried',
#  105: 'Heart',
#  106: '2',
#  107: 'quickly',
#  108: 'there',
#  109: 'pace',
#  110: 'liking',
#  111: 'Hot',
#  112: 'visited',
#  113: 'grab',
#  114: 'pho',
#  115: 'somewhat',
#  116: 'needs',
#  117: 'bug',
#  118: 'favorite',
#  119: 'STEP',
#  120: 'shirt',
#  121: 'buying',
#  122: 'alone',
#  123: 'suggest',
#  124: 'front',
#  125: 'later',
#  126: 'her',
#  127: 'falling',
#  128: 'glad',
#  129: 'cramming',
#  130: 'world',
#  131: 'transcendant',
#  132: 'Spend',
#  133: 'Las',
#  134: 'second',
#  135: 'Burger',
#  136: 'turn',
#  137: 'pissd',
#  138: 'ourselves',
#  139: 'sewer',
#  140: 'next',
#  141: 'bowl',
#  142: 'cash',
#  143: 'flavorless',
#  144: 'AND',
#  145: 'Mandalay',
#  146: 'handed',
#  147: 'far',
#  148: 'eyed',
#  149: 'gyros',
#  150: 'excellent',
#  151: 'Terrible',
#  152: 'spring',
#  153: 'readers',
#  154: 'Perhaps',
#  155: 'beautifully',
#  156: 'interesting',
#  157: 'AYCE',
#  158: 'tea',
#  159: 'water',
#  160: 'sangria',
#  161: 'takeout',
#  162: 'elegantly',
#  163: 'outstanding',
#  164: 'must',
#  165: 'anyone',
#  166: 'college',
#  167: 'Our',
#  168: 'email',
#  169: 'considering',
#  170: 'cooked',
#  171: 'raving',
#  172: 'Sun',
#  173: 'tables',
#  174: 'decide',
#  175: '40',
#  176: ',',
#  177: 'asking',
#  178: 'double',
#  179: 'imagine',
#  180: 'Bouchon',
#  181: 'combo',
#  182: 'unfortunately',
#  183: 'eat',
#  184: ')',
#  185: 'worst/annoying',
#  186: 'Stopped',
#  187: '7',
#  188: 'mozzarella',
#  189: 'which',
#  190: 'leftover',
#  191: 'flavorful',
#  192: 'Love',
#  193: 'Rick',
#  194: 'golden-crispy',
#  195: 'yellowtail',
#  196: 'Ryan',
#  197: 'final',
#  198: 'family',
#  199: 'industry',
#  200: 'apology',
#  201: 'prepare',
#  202: 'send',
#  203: 'feel',
#  204: 'Mexican',
#  205: 'nicest',
#  206: 'reheated',
#  207: 'drawing',
#  208: 'Japanese',
#  209: 'over-hip',
#  210: 'disgrace',
#  211: 'relax',
#  212: 'disgraceful',
#  213: 'disgusting',
#  214: 'voted',
#  215: 'chocolate',
#  216: 'Coming',
#  217: 'space',
#  218: 'reminded',
#  219: 'feeling',
#  220: 'closed',
#  221: 'luck',
#  222: 'Luke',
#  223: 'Nargile',
#  224: 'none',
#  225: 'towards',
#  226: 'obviously',
#  227: 'Be',
#  228: 'light',
#  229: 'TOTAL',
#  230: 'help',
#  231: 'pricey',
#  232: 'home',
#  233: 'tuna',
#  234: 'experienced',
#  235: 'ate',
#  236: 'portion',
#  237: 'servers',
#  238: 'amazing',
#  239: 'Ample',
#  240: 'happier',
#  241: 'gratuity',
#  242: 'bathroom',
#  243: 'deal',
#  244: 'quick',
#  245: 'Poor',
#  246: 'styrofoam',
#  247: 'upgrading',
#  248: 'Lastly',
#  249: 'tolerance',
#  250: 'impressed',
#  251: 'three',
#  252: 'BACK',
#  253: 'Pineapple',
#  254: 'does',
#  255: 'potatoes',
#  256: 'Third',
#  257: 'Mmmm',
#  258: 'receives',
#  259: 'plus',
#  260: 'pancake',
#  261: 'Mediterranean',
#  262: 'authentic',
#  263: 'Interesting',
#  264: 'crusty',
#  265: 'Cotta',
#  266: 'crispy',
#  267: 'Madison',
#  268: 'fry',
#  269: 'if',
#  270: 'cheated',
#  271: 'chewy',
#  272: 'Tonight',
#  273: 'rest',
#  274: 'works',
#  275: 'rapidly',
#  276: 'passed',
#  277: 'vain',
#  278: 'trippy',
#  279: 'poorly',
#  280: 'disappointing',
#  281: 'lacked',
#  282: 'THAT',
#  283: 'Hopefully',
#  284: 'binge',
#  285: 'quit',
#  286: 'untoasted',
#  287: 'hereas',
#  288: 'brings',
#  289: 'yay',
#  290: 'saganaki',
#  291: 'Sushi',
#  292: 'review',
#  293: 'Caballero',
#  294: 'actual',
#  295: 'verge',
#  296: 'arrived',
#  297: '.',
#  298: 'area',
#  299: 'honor',
#  300: 'salsa',
#  301: 'shoe',
#  302: 'seasonal',
#  303: 'sauce',
#  304: 'bus',
#  305: 'hooked',
#  306: 'quantity',
#  307: 'behind',
#  308: 'bamboo',
#  309: 'pastry',
#  310: 'By',
#  311: 'spotty',
#  312: 'grossed',
#  313: 'Four',
#  314: 'beautiful',
#  315: 'properly',
#  316: 'refrained',
#  317: '.off',
#  318: 'store',
#  319: 'free',
#  320: 'dinners',
#  321: 'working/eating',
#  322: 'gluten',
#  323: 'prime',
#  324: 'thru',
#  325: 'instead',
#  326: 'airport',
#  327: 'price',
#  328: 'eggs',
#  329: 'over-priced',
#  330: 'editing',
#  331: 'glass',
#  332: 'powdered',
#  333: 'quaint',
#  334: 'looks',
#  335: '11.99',
#  336: 'Boy',
#  337: 'incredibly',
#  338: 'forty',
#  339: 'latte',
#  340: 'Similarly',
#  341: 'lawyers',
#  342: 'honestly',
#  343: 'low',
#  344: 'papers',
#  345: 'shrimp',
#  346: 'clean',
#  347: 'Furthermore',
#  348: 'pepper',
#  349: 'concept',
#  350: 'unhealthy',
#  351: 'mein',
#  352: 'Ha',
#  353: 'friendly',
#  354: 'besides',
#  355: 'ridiculous',
#  356: 'vacant',
#  357: 'pink',
#  358: 'But',
#  359: 'There',
#  360: 'screwed',
#  361: 'beyond',
#  362: '-',
#  363: 'where',
#  364: 'gooodd',
#  365: 'ever',
#  366: 'boy',
#  367: 'warm',
#  368: 'here',
#  369: 'dusted',
#  370: 'potato',
#  371: 'inside',
#  372: 'bill',
#  373: 'Needless',
#  374: 'Toast',
#  375: 'rice',
#  376: 'offered',
#  377: 'go',
#  378: 'got',
#  379: 'boot',
#  380: 'hella',
#  381: 'yummy',
#  382: 'am',
#  383: 'idea',
#  384: 'truly',
#  385: 'forth',
#  386: 'iced',
#  387: 'perfectly',
#  388: 'cheese',
#  389: 'multiple',
#  390: 'meatballs',
#  391: 'deliver',
#  392: 'together',
#  393: 'fruit',
#  394: 'Gourmet',
#  395: 'one',
#  396: 'high',
#  397: 'gotten',
#  398: 'decided',
#  399: 'San',
#  400: 'paper',
#  401: 'fair',
#  402: 'hardly',
#  403: 'nasty',
#  404: 'Definitely',
#  405: 'please',
#  406: 'curry',
#  407: 'experience',
#  408: 'dead',
#  409: 'apologize',
#  410: 'dollars',
#  411: 'cafe',
#  412: 'publicly',
#  413: 'sub',
#  414: 'events',
#  415: 'exactly',
#  416: 'served',
#  417: 'but',
#  418: 'tiny',
#  419: 'Avoid',
#  420: 'scallop',
#  421: 'courteous',
#  422: 'round',
#  423: 'regular',
#  424: 'or',
#  425: 'medium',
#  426: 'Every',
#  427: 'My',
#  428: 'over-whelm',
#  429: 'concern',
#  430: 'boba',
#  431: 'relationship',
#  432: 'wrong',
#  433: 'steakhouse',
#  434: 'At',
#  435: 'Food',
#  436: 'tap',
#  437: 'been-stepped-in-and-tracked-everywhere',
#  438: 'Seafood',
#  439: 'sandwiches',
#  440: 'set',
#  441: 'someone',
#  442: 'better',
#  443: 'spicy',
#  444: '3/4ths',
#  445: 'struggle',
#  446: 'Go',
#  447: 'martini',
#  448: 'running',
#  449: 'any',
#  450: 'silently',
#  451: 'accommodations',
#  452: 'IN',
#  453: 'MUST',
#  454: "'s",
#  455: '10+',
#  456: 'simple',
#  457: 'angry',
#  458: 'almost',
#  459: 'rushed',
#  460: 'customers',
#  461: 'Lemon',
#  462: 'pop',
#  463: 'who',
#  464: 'NONE',
#  465: 'Casino',
#  466: 'Sorry',
#  467: 'operation',
#  468: 'she',
#  469: '$',
#  470: 'tragedy',
#  471: '..ohhh',
#  472: 'worries',
#  473: 'want',
#  474: 'place',
#  475: 'Reasonably',
#  476: 'non-customer',
#  477: 'wash',
#  478: 'those',
#  479: 'accomodate',
#  480: 'haunt',
#  481: 'Plus',
#  482: 'do',
#  483: 'shall',
#  484: 'Bloody',
#  485: 'NOW',
#  486: 'Awesome',
#  487: 'another',
#  488: 'Crystals',
#  489: 'might',
#  490: 'buffets',
#  491: 'side',
#  492: 'They',
#  493: 'pucks',
#  494: 'not',
#  495: 'seating',
#  496: 'last',
#  497: 'rich',
#  498: 'Rock',
#  499: 'yellow',
#  500: 'caring',
#  501: 'fuzzy',
#  502: 'that',
#  503: 'wrap',
#  504: 'talk',
#  505: 'Christmas',
#  506: 'Same',
#  507: 'pretty',
#  508: 'complain',
#  509: 'cause',
#  510: 'being',
#  511: 'hummus',
#  512: "'re",
#  513: 'about',
#  514: 'entrees',
#  515: 'inspired',
#  516: 'bottom',
#  517: 'Highly',
#  518: "'ve",
#  519: 'sunglasses',
#  520: 'blame',
#  521: 'much',
#  522: 'showed',
#  523: 'High-quality',
#  524: 'skimp',
#  525: 'self',
#  526: 'has',
#  527: 'tasty',
#  528: 'name',
#  529: 'Tasted',
#  530: 'Delicious',
#  531: 'between',
#  532: 'although',
#  533: 'wagyu',
#  534: 'eggplant',
#  535: 'years',
#  536: 'horrible',
#  537: 'connoisseur',
#  538: '2007',
#  539: 'fine',
#  540: 'mood',
#  541: 'others',
#  542: 'Thai',
#  543: 'breaks',
#  544: 'manager',
#  545: 'wire',
#  546: 'boiled',
#  547: 'Mary',
#  548: 'One',
#  549: 'Shop',
#  550: 'corporation',
#  551: 'smaller',
#  552: 'sandwich',
#  553: 'cut',
#  554: 'theft',
#  555: 'flavourful',
#  556: 'end',
#  557: 'third',
#  558: 'Bean',
#  559: 'Pho',
#  560: 'sad',
#  561: 'batter',
#  562: 'waitresses',
#  563: 'ok',
#  564: 'wish',
#  565: 'profound',
#  566: 'staying',
#  567: 'privileged',
#  568: 'smelled',
#  569: 'looking',
#  570: 'bank',
#  571: 'devine',
#  572: 'fucking',
#  573: 'dates',
#  574: 'seated',
#  575: 'tots',
#  576: 'andddd',
#  577: 'wedges',
#  578: 'dessert',
#  579: 'plantains',
#  580: 'yum',
#  581: 'satisfied',
#  582: 'sure',
#  583: 'try',
#  584: 'puréed',
#  585: 'sound',
#  586: 'classic',
#  587: 'had',
#  588: '30s',
#  589: 'ahead',
#  590: 'public',
#  591: 'jerk',
#  592: 'fish',
#  593: 'vibe',
#  594: 'strings',
#  595: 'plethora',
#  596: 'pile',
#  597: 'eel',
#  598: 'bone',
#  599: 'dough',
#  600: 'Really',
#  601: 'Disappointing',
#  602: 'bad',
#  603: 'shopping',
#  604: 'Phoenix',
#  605: 'supposed',
#  606: 'bakery',
#  607: 'reading',
#  608: 'meatloaf',
#  609: 'return',
#  610: 'prompt',
#  611: 'bar',
#  612: 'EVER',
#  613: 'donut',
#  614: 'sugar',
#  615: 'myself',
#  616: 'stars',
#  617: 'Would',
#  618: 'hoping',
#  619: 'imaginative',
#  620: 'yukon',
#  621: 'calligraphy',
#  622: 'wings',
#  623: 'SHOULD',
#  624: 'occasions',
#  625: 'combination',
#  626: 'beer',
#  627: 'appetizer',
#  628: 'top',
#  629: 'decision',
#  630: 'understand',
#  631: 'long',
#  632: 'violinists',
#  633: 'stay',
#  634: 'patio',
#  635: 'lot',
#  636: 'hardest',
#  637: 'stuff',
#  638: 'been',
#  639: 'exceptional',
#  640: 'wildly',
#  641: '90',
#  642: 'WHAT',
#  643: 'lack',
#  644: 'spice',
#  645: 'choux',
#  646: 'apart',
#  647: 'Long',
#  648: 'Joey',
#  649: 'greasy',
#  650: 'Ninja',
#  651: 'Flower',
#  652: 'restaurant',
#  653: 'date',
#  654: 'I',
#  655: 'wound',
#  656: 'Steak',
#  657: 'Based',
#  658: 'meat',
#  659: 'still',
#  660: 'worse',
#  661: 'Soi',
#  662: 'spices',
#  663: 'sashimi',
#  664: 'acknowledged',
#  665: 'providing',
#  666: 'carbs',
#  667: 'app',
#  668: 'Bad',
#  669: 'opposed',
#  670: 'business',
#  671: 'outdoor',
#  672: 'GREAT',
#  673: 'street',
#  674: 'oysters',
#  675: 'super',
#  676: 'gone',
#  677: 'raspberry',
#  678: 'Roll',
#  679: 'possible',
#  680: 'style',
#  681: 'performed',
#  682: 'fluffy',
#  683: 'godfathers',
#  684: 'enough..',
#  685: 'milk',
#  686: 'Nothing',
#  687: 'accident',
#  688: 'sore',
#  689: 'Host',
#  690: 'while',
#  691: 'Maria',
#  692: 'poop',
#  693: 'bloddy',
#  694: 'Experience',
#  695: 'appealing',
#  696: 'people',
#  697: 'like',
#  698: 'Hawaiian',
#  699: 'TV',
#  700: 'Great',
#  701: 'use',
#  702: 'boring',
#  703: 'professional',
#  704: 'find',
#  705: 'relleno',
#  706: 'clue',
#  707: 'Overpriced',
#  708: 'were',
#  709: 'right',
#  710: 'Which',
#  711: 'choose',
#  712: 'trips',
#  713: 'mediocre',
#  714: 'favor',
#  715: 'cakes',
#  716: 'new',
#  717: 'power',
#  718: 'Everything',
#  719: 'fell',
#  720: 'steaks',
#  721: 'short',
#  722: 'recommending',
#  723: 'Eggplant',
#  724: 'downside',
#  725: 'legit',
#  726: 'itself',
#  727: 'happy',
#  728: 'platter',
#  729: 'paid',
#  730: 'sticks',
#  731: 'recall',
#  732: 'despicable',
#  733: 'cashier',
#  734: 'menu',
#  735: 'menus',
#  736: 'pastas',
#  737: 'Those',
#  738: 'blue',
#  739: 'Strike',
#  740: 'salmon',
#  741: 'Cod',
#  742: 'cost',
#  743: 'ones',
#  744: 'living',
#  745: 'Scottsdale',
#  746: 'done',
#  747: 'sexy',
#  748: 'The',
#  749: 'under',
#  750: 'Although',
#  751: 'absolutely',
#  752: 'businesses',
#  753: 'dreamed',
#  754: 'solid',
#  755: 'extensive',
#  756: 'me',
#  757: 'companions',
#  758: 'hot',
#  759: 'jewel',
#  760: 'oh',
#  761: 'sucked',
#  762: 'hour',
#  763: 'coupons',
#  764: 'personable',
#  765: 'Plater',
#  766: 'overwhelmed',
#  767: 'reasonably',
#  768: 'MANY',
#  769: 'fantastic',
#  770: 'recommended',
#  771: 'joy',
#  772: '.way',
#  773: 'Hands',
#  774: 'of',
#  775: 'eyes',
#  776: 'Sadly',
#  777: 'was',
#  778: 'hair',
#  779: 'MGM',
#  780: 'giant',
#  781: 'neither',
#  782: 'nutshell',
#  783: 'why',
#  784: 'fairly',
#  785: 'REAL',
#  786: 'gold',
#  787: 'absolutley',
#  788: 'cream',
#  789: 'selections',
#  790: 'Cape',
#  791: 'Best',
#  792: 'Area',
#  793: 'market',
#  794: 'chefs',
#  795: 'Baba',
#  796: 'avoid',
#  797: 'peach',
#  798: 'What',
#  799: 'food',
#  800: 'left',
#  801: 'chickens',
#  802: 'thing',
#  803: 'T.',
#  804: '70+',
#  805: 'tartare',
#  806: '1979',
#  807: 'up',
#  808: 'NASTY',
#  809: 'amount',
#  810: 'salty',
#  811: 'hopes',
#  812: 'Brushfire',
#  813: 'refreshing',
#  814: 'wants',
#  815: 'see',
#  816: 'case',
#  817: 'serving',
#  818: 'patty',
#  819: 'complaints',
#  820: 'TOLD',
#  821: '15',
#  822: 'hearts',
#  823: 'smoothies',
#  824: 'rating',
#  825: 'did',
#  826: 'slow',
#  827: 'small',
#  828: 'Come',
#  829: 'tasted',
#  830: 'an',
#  831: 'person',
#  832: 'cuisine',
#  833: 'menu/',
#  834: 'filling',
#  835: 'Grill',
#  836: 'ravoli',
#  837: 'As',
#  838: 'Otto',
#  839: 'Blah',
#  840: 'winner',
#  841: 'so',
#  842: 'warmer',
#  843: 'close',
#  844: '7.85',
#  845: 'strangers',
#  846: 'soon',
#  847: 'parents',
#  848: 'overall',
#  849: 'We',
#  850: 'spaghetti',
#  851: 'deep',
#  852: 'pecan',
#  853: 'Stars',
#  854: 'summary',
#  855: 'club',
#  856: 'places',
#  857: 'somehow',
#  858: 'olives',
#  859: 'less',
#  860: 'reservation',
#  861: 'rge',
#  862: 'ignore',
#  863: 'longer',
#  864: 'Risotto',
#  865: 'become',
#  866: 'attack',
#  867: 'looked',
#  868: 'postinos',
#  869: 'whether',
#  870: 'steak',
#  871: 'appetizers',
#  872: 'disbelief',
#  873: 'unique',
#  874: 'Vegas',
#  875: 'class',
#  876: '30',
#  877: 'you',
#  878: 'enough',
#  879: 'welcome',
#  880: 'mojitos',
#  881: 'satifying',
#  882: 'cocktails',
#  883: 'Magazine',
#  884: 'mall',
#  885: 'Eew',
#  886: 'batch',
#  887: 'hottest',
#  888: 'took',
#  889: 'full',
#  890: 'brother',
#  891: 'chipolte',
#  892: 'WORST',
#  893: 'uploaded',
#  894: 'our',
#  895: 'guacamole',
#  896: 'tops',
#  897: 'spicier',
#  898: 'shots',
#  899: 'now',
#  900: 'we',
#  901: 'ethic',
#  902: 'Buldogis',
#  903: 'VERY',
#  904: 'twice',
#  905: 'Pizza',
#  906: 'hip',
#  907: 'flavors',
#  908: 'missed',
#  909: 'venture',
#  910: 'Now',
#  911: 'Mushroom',
#  912: 'coming',
#  913: 'North',
#  914: 'pleased',
#  915: 'Not',
#  916: 'spots',
#  917: 'received',
#  918: 'Taco',
#  919: 'section',
#  920: 'crowds',
#  921: 'weekend',
#  922: 'ordering',
#  923: 'smoke',
#  924: 'LEGIT',
#  925: 'at',
#  926: 'accountant',
#  927: 'correct',
#  928: 'handmade',
#  929: 'outta',
#  930: 'rolled',
#  931: 'Edinburgh',
#  932: 'Paying',
#  933: 'point',
#  934: 'boyfriend',
#  935: 'Anyways',
#  936: 'stupid',
#  937: 'disappointed',
#  938: 'maybe',
#  939: 'Why',
#  940: 'military',
#  941: 'vegetables',
#  942: 'ESTABLISHMENT',
#  943: 'She',
#  944: 'difference',
#  945: 'Extremely',
#  946: 'enjoyable',
#  947: 'orders',
#  948: 'forever',
#  949: 'loudly',
#  950: 'carpaccio',
#  951: 'ignored',
#  952: 'Only',
#  953: 'modern',
#  954: 'memory',
#  955: 'capers',
#  956: 'mention',
#  957: 'can',
#  958: 'Worse',
#  959: '.the',
#  960: '6',
#  961: 'Shrimp-',
#  962: 'atmosphere.1',
#  963: 'FS',
#  964: 'leather',
#  965: 'frozen',
#  966: 'Macarons',
#  967: 'fact',
#  968: 'slaw',
#  969: 'honest',
#  970: 'forgetting',
#  971: 'bartenders',
#  972: 'anything',
#  973: 'gem',
#  974: 'piece',
#  975: 'attention',
#  976: 'sides',
#  977: '``',
#  978: 'HOUR',
#  979: 'thanks',
#  980: 'Philadelphia',
#  981: 'duck',
#  982: 'live',
#  983: 'BBQ',
#  984: 'Café',
#  985: 'wonderful',
#  986: 'Aria',
#  987: 'need',
#  988: 'contained',
#  989: 'returning',
#  990: 'come',
#  991: 'trimmed',
#  992: 'because',
#  993: 'seemed',
#  994: 'smeared',
#  995: 'efficient',
#  996: 'loves',
#  997: '*',
#  998: 'NO',
#  999: 'delish',
#  ...}

# %% [markdown]
# ## 轉換句子為bag of words型式

# %%
def _get_bag_of_words_vector(sentence, word_index_dic, whole_words):
    sentence = sentence
    vector = np.zeros(len(whole_words))
    for word in nltk.word_tokenize(sentence):
        if word in whole_words:
            vector[word_index[word]]+=1
    return vector

# %%
_get_bag_of_words_vector('Wow... Loved this place.', word_index, whole_words)
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])
